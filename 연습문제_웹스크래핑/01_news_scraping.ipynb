# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.5
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: anaconda-auth, anaconda-catalogs, anaconda-client, anaconda-project, conda, conda-build, conda-libmamba-solver, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, PyGithub, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup
# Out:
# WARNING: Package(s) not found: beautifulsoup

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.5
# bs4 버전 = 4.13.5

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
url = 'https://news.daum.net/economy'
print(url)

# 요청 헤더 설정 : 브라우저 정보 ( 사람처럼 보이게 하기 위함 )
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)


print(type(res))
print(res.status_code)
# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
# BeautifulSoup 객체 생성  

res.encoding = 'utf-8'

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    a_tags = soup.select('ul.list_newsheadline2 li')
    print(type(a_tags), len(a_tags))
    for li_tag in a_tags:
        a_tag = li_tag.find('a')
        link = a_tag['href']	
            
        strong_tag = li_tag.select_one('div.cont_thumb strong.tit_txt')
        title = strong_tag.text 
        print(link)
        print(title)
# Out:
# https://news.daum.net/economy
# <class 'requests.models.Response'>
# 200
# <class 'bs4.element.ResultSet'> 9
# https://v.daum.net/v/20260206110503592
# 지난해 경상수지, 반도체 훈풍 발판 '흑자' 신기록 쏟아졌다⋯한은 "올해도 긍정적" [종합]
# https://v.daum.net/v/20260206110124350
# [타파의 시선] 4천억 '탈세왕' 마저 감싸는 국세청의 비밀주의
# https://v.daum.net/v/20260206105208919
# '외인 vs 개인 수급전쟁'..삼전·닉스 4조원 어치 던진 외국인 떠나나?
# https://v.daum.net/v/20260206104305391
# 쭉쭉 늘더니 국민연금마저 뛰어넘었다…서학개미 해외주식투자 450억달러
# https://v.daum.net/v/20260206101901115
# '반도체 활황'에 작년 경상흑자 1천231억弗…12월 187억弗 '역대 최대'(종합)
# https://v.daum.net/v/20260206100609345
# 달 탐사로 가속화되는 우주 시장 개척 경쟁! [취재파일]
# https://v.daum.net/v/20260206095303503
# 신학기 앞두고 '전월세 사기 주의보'…"시·도청 도움 받으세요"
# https://v.daum.net/v/20260206090942194
# ‘폭등→폭락→폭등’ 롤러코스터 증시 뒤에는 스마트해진 개인이 있다
# https://v.daum.net/v/20260206090632078
# ‘호카 사태’와 CEO 리스크… 폭행 논란 경영자 탓 실적악화 불 보듯
